# %%
from IPython.display import Image

# Just give the path to your saved figure
Image(filename="mini_report.png")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("mini_report.png")
plt.figure(figsize=(10,8))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
import matplotlib.image as mpimg

fig, axs = plt.subplots(1, 2, figsize=(18, 8))

for ax, fn, title in zip(
    axs,
    ["class_bars_seed1337_norm_images.png", "class_bars_seed1337_norm_annots.png"],
    ["Normalized by Image Count", "Normalized by Annotation Count"]
):
    img = mpimg.imread(fn)
    ax.imshow(img)
    ax.axis("off")
    ax.set_title(title, fontsize=14)

plt.tight_layout()
plt.show()
